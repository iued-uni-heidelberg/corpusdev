# %% [markdown]
# <a href="https://colab.research.google.com/github/iued-uni-heidelberg/corpusdev/blob/main/Transcribe_Audio_With_Whisper_Ukrainian_UK_UA_v2_YouTube_update.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ✨ README
#
# This is the companion Colab for the article "[How to transcribe your audio to text, for free (with SRTs/VTTs!)](https://wandb.ai/wandb_fc/gentle-intros/reports/How-to-transcribe-your-audio-to-text-for-free-with-SRTs-VTTs---VmlldzozNDczNTI0)".
#
# This Colab shows how to use OpenAI's Whisper to transcribe audio and audiovisual files, and how to save that transcription as a plain text file or as a VTT/SRT caption file.

# %% [markdown]
# # 📎 Documentation
#
# * `input_format`: The source of the audio/video file to be transcribed
#   * `youtube`: A YouTube video
#     * The transcribed file(s) are saved to this Colab, and will be deleted when the Colab runtime is disconnected.
#   * `gdrive`: A file in your Google Drive account
#     * If you select this option, you will need to allow this notebook to connect to your Google Drive account.
#     * The transcribed file(s) are saved to the same folder as the original file.
#   * `local`: A local file that you have uploaded to this Colab
#     * If you select this option, you will need to first upload the file to the Files tab (see Step 1 [here](https://wandb.ai/wandb_fc/gentle-intros/reports/How-to-transcribe-your-audio-to-text-for-free-with-SRTs-VTTs---VmlldzozMzc1MzU3)).
#     * The transcribed file(s) are saved to this Colab, and will be deleted when the Colab runtime is disconnected.
# * `file`: The URL of the YouTube video or the path of the audio file to be transcribed.
#   * Example: `file = "https://www.youtube.com/watch?v=AUDIO"` (transcribing a YouTube video)
#   * Example: `file = "/content/drive/My Drive/AUDIO.mp3"` (transcribing a Google Drive file)
#   * Example: `file = "/content/AUDIO.mp3"` (transcribing a local file)
# * `plain`: Whether to save the transcription as a text file or not.
# * `srt`: Whether to save the transcription as an SRT file or not.
# * `vtt`: Whether to save the transcription as a VTT file or not.
# * `tsv`: Whether to save the transcription as a TSV (tab-separated values) file or not.
# * `download`: Whether to download the transcribed file(s) or not.

# %% [markdown]
# ## Download audio files, if you know the URL

# %%
# !wget https://heibox.uni-heidelberg.de/f/9a8ed35f5f1e46a2b695/?dl=1
# !mv index.html?dl=1 SCH_T3q9b256.mp3
# !wget https://heibox.uni-heidelberg.de/f/5c4bcecdedab4310a672/?dl=1
# !mv index.html?dl=1 SCHWARZWALDMAEDEL_T3.mp4

# %%
# @title 🌴 Change the values in this section

# @markdown Select the source of the audio/video file to be transcribed
input_format = "youtube" #@param ["youtube", "gdrive", "local"]

# @markdown Enter the URL of the YouTube video or the path of the audio file to be transcribed
file = "https://www.youtube.com/watch?v=qU4uNAdejAQ" #@param {type:"string"}

#@markdown Click here if you'd like to save the transcription as text file
plain = True #@param {type:"boolean"}

# @markdown Click here if you'd like to save the transcription as an SRT file
srt = True #@param {type:"boolean"}

#@markdown Click here if you'd like to save the transcription as a VTT file
vtt = True #@param {type:"boolean"}

#@markdown Click here if you'd like to save the transcription as a TSV file
tsv = True #@param {type:"boolean"}

#@markdown Click here if you'd like to download the transcribed file(s) locally
download = True #@param {type:"boolean"}

# %% [markdown]
# # 🛠 Set Up
#
# The blocks below install all of the necessary Python libraries (including Whisper), configures Whisper, and contains code for various helper functions.

# %% [markdown]
# ## 🤝 Dependencies

# %%
# Dependencies

# !pip install -q pytube
# !pip install -q git+https://github.com/openai/whisper.git
# !pip install yt-dlp


import os, re
import torch
from pathlib import Path

import whisper
from whisper.utils import get_writer

import yt_dlp
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for openai-whisper (pyproject.toml) ... done
# Collecting yt-dlp
#   Downloading yt_dlp-2025.9.5-py3-none-any.whl.metadata (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 kB 6.5 MB/s eta 0:00:00
# Downloading yt_dlp-2025.9.5-py3-none-any.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 66.9 MB/s eta 0:00:00
# Installing collected packages: yt-dlp
# Successfully installed yt-dlp-2025.9.5

# %% [markdown]
# ## 👋 Whisper configuration
#
# This Colab use `medium.en`, [the medium-sized, English-only](https://github.com/openai/whisper#available-models-and-languages) Whisper model.

# %%
# Use CUDA, if available
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# Load the desired model
# model = whisper.load_model("medium.en").to(DEVICE)
model = whisper.load_model("medium").to(DEVICE)
# model = whisper.load_model("large").to(DEVICE)
## large
# Out:
# 100%|██████████████████████████████████████| 1.42G/1.42G [00:09<00:00, 168MiB/s]

# %% [markdown]
# ## 💪 YouTube helper functions
#
# Code for helper functions when running Whisper on a YouTube video.

# %%
def to_snake_case(name):
    return name.lower().replace(" ", "_").replace(":", "_").replace("__", "_")

def download_youtube_audio(url, out_dir=".", file_name=None):
    Path(out_dir).mkdir(exist_ok=True)
    output_template = str(Path(out_dir, "%(title)s.%(ext)s")) if file_name is None else str(Path(out_dir, file_name))

    ydl_opts = {
        "format": "bestaudio/best",
        "outtmpl": output_template,
        "postprocessors": [{
            "key": "FFmpegExtractAudio",
            "preferredcodec": "mp3",
            "preferredquality": "192",
        }],
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(url, download=True)
        return ydl.prepare_filename(info).replace(".webm", ".mp3").replace(".m4a", ".mp3")

# %% [markdown]
# # ✍ Transcribing with Whisper
#
# Ultimately, calling Whisper is as easy as one line!
# * `result = model.transcribe(file)`
#
# The majority of this new `transcribe_file` function is actually just for exporting the results of the transcription as a text, VTT, or SRT file.

# %%
def transcribe_file(model, file, plain, srt, vtt, tsv, download):
    """
    Runs Whisper on an audio file

    Parameters
    ----------
    model: Whisper
        The Whisper model instance.

    file: str
        The file path of the file to be transcribed.

    plain: bool
        Whether to save the transcription as a text file or not.

    srt: bool
        Whether to save the transcription as an SRT file or not.

    vtt: bool
        Whether to save the transcription as a VTT file or not.

    tsv: bool
        Whether to save the transcription as a TSV file or not.

    download: bool
        Whether to download the transcribed file(s) or not.

    Returns
    -------
    A dictionary containing the resulting text ("text") and segment-level details ("segments"), and
    the spoken language ("language"), which is detected when `decode_options["language"]` is None.
    """
    file_path = Path(file)
    print(f"Transcribing file: {file_path}\n")

    output_directory = file_path.parent

    # Run Whisper
    result = model.transcribe(file, verbose = False, language = "uk")

    if plain:
        txt_path = file_path.with_suffix(".txt")
        print(f"\nCreating text file")

        with open(txt_path, "w", encoding="utf-8") as txt:
            txt.write(result["text"])
    if srt:
        print(f"\nCreating SRT file")
        srt_writer = get_writer("srt", output_directory)
        srt_writer(result, str(file_path.stem))

    if vtt:
        print(f"\nCreating VTT file")
        vtt_writer = get_writer("vtt", output_directory)
        vtt_writer(result, str(file_path.stem))

    if tsv:
        print(f"\nCreating TSV file")

        tsv_writer = get_writer("tsv", output_directory)
        tsv_writer(result, str(file_path.stem))

    if download:
        from google.colab import files

        colab_files = Path("/content")
        stem = file_path.stem

        for colab_file in colab_files.glob(f"{stem}*"):
            if colab_file.suffix in [".txt", ".srt", ".vtt", ".tsv"]:
                print(f"Downloading {colab_file}")
                files.download(str(colab_file))

    return result

# %% [markdown]
# # 💬 Whisper it!
#
# This block actually calls `transcribe_file` 😉

# %%
if input_format == "youtube":
    # Download the audio stream of the YouTube video
    # print(f"Downloading audio stream: {audio}")
    audio = download_youtube_audio(file)

    # Run Whisper on the audio stream
    result = transcribe_file(model, audio, plain, srt, vtt, tsv, download)
elif input_format == "gdrive":
    # Authorize a connection between Google Drive and Google Colab
    from google.colab import drive
    drive.mount('/content/drive')

    # Run Whisper on the specified file
    result = transcribe_file(model, file, plain, srt, vtt, tsv, download)
elif input_format == "local":
    # Run Whisper on the specified file
    result = transcribe_file(model, file, plain, srt, vtt, tsv, download)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=qU4uNAdejAQ
# [youtube] qU4uNAdejAQ: Downloading webpage
# [youtube] qU4uNAdejAQ: Downloading tv simply player API JSON
# [youtube] qU4uNAdejAQ: Downloading tv client config
# [youtube] qU4uNAdejAQ: Downloading player 0e6689e2-main
# [youtube] qU4uNAdejAQ: Downloading tv player API JSON
# [info] qU4uNAdejAQ: Downloading 1 format(s): 251
# [download] Sleeping 3.00 seconds as required by the site...
# [download] Destination: 🔴 Новини на 8_00 7 січня. “Шахеди” атакували пів України.webm
# [download] 100% of   10.59MiB in 00:00:01 at 7.52MiB/s
# [ExtractAudio] Destination: 🔴 Новини на 8_00 7 січня. “Шахеди” атакували пів України.mp3
# Deleting original file 🔴 Новини на 8_00 7 січня. “Шахеди” атакували пів України.webm (pass -k to keep)
# Transcribing file: 🔴 Новини на 8_00 7 січня. “Шахеди” атакували пів України.mp3
# 100%|██████████| 86788/86788 [04:11<00:00, 345.73frames/s]
# Creating text file
#
# Creating SRT file
#
# Creating VTT file
#
# Creating TSV file
# Downloading /content/🔴 Новини на 8_00 7 січня. “Шахеди” атакували пів України.txt

# %%
# !cp "/content/🔴 Новини на 8_00 7 січня. “Шахеди” атакували пів України.mp3" "/content/news-uk.mp3"

# %%
#
# !whisper news-uk.mp3 --model medium --language Ukrainian --task transcribe
# Out:
# [00:00.000 --> 00:05.000]  Вітаю! 683-й день повномештабної війни Росії проти України.
# [00:05.000 --> 00:10.000]  Час новин в ефірі загальнонационального марафону. Мене звати Ольга Бутко. Починаємо.
# [00:10.000 --> 00:16.000]  І розпочнемо зі зведень від інштабу ЗСУ. На передовій було 45 бойових зіткнень.
# [00:16.000 --> 00:20.000]  Ворог здійсни 18 безуспішних штурмових дій на позиції Сил оборони.
# [00:20.000 --> 00:26.000]  Зокрема, на Авдіївському напрямку наші захисники відбили понад 20 атак противника і 9 на Мар'їнському.
# [00:26.000 --> 00:31.000]  За добу російські загарбники завдали 9 ракетних та 84 авіаційних ударів.
# [00:31.000 --> 00:38.000]  Здійснили півсотню обстрілів із реактивних систем залпового вогню по позиціях наших військ та містах і селах.
# [00:38.000 --> 00:44.000]  Серед мирних є загиблі та поранені, а також руйнування житлових будинків та цивільної інфраструктури.
# [00:44.000 --> 00:51.000]  У відповідь авіація, Сила оборони та підрозділ ракетних військ вразили понад 20 районів, де скупчилися ворожі війська.
# [00:51.000 --> 00:56.000]  Знищили занітно-ракетний комплекс, два пункти управління, склад боєприпасів,
# [06:51.000 --> 06:55.000]  Ми виїжджаємо туди. Останній раз, як були, це було Хромове.
# [06:55.000 --> 07:02.000]  Сіяли на Хромовому. В Часовому Яру базувалися там, а на Хромовому виїжджали на роботу.
# [07:02.000 --> 07:09.000]  Військові розповідають про один з найгарячіших напрямків фронту. Зізнаються, працювати там стає дедалі важче.
# [07:10.000 --> 07:15.000]  Це був бій. Ближчі 10 метрів, коли нас скрили.
# [07:15.000 --> 07:19.000]  Нас почали закадати топово гранатами.
# [07:19.000 --> 07:23.000]  Навіть не могли вилізти, щоб вістрілюватися.
# [07:23.000 --> 07:31.000]  До тих пір, поки ми не почали кидати гранати, які навіть прилітали з наших гранат до нас, об'єдки вони цеплялися.
# [07:31.000 --> 07:37.000]  Але це був вихід з ситуації. Ми з нього вийшли і дали гарний бій.
# [07:37.000 --> 07:41.000]  В прошлому році, коли ми перший раз виїжджали, то так тяжко не було.
# [07:41.000 --> 07:46.000]  Не було скільки дронів, і вони навчилися бить.
# [07:46.000 --> 07:52.000]  Тоді з десяти снарядів прилетало по тобі два, а це з десяти уже сім попадає.
# [07:52.000 --> 07:58.000]  Зараз вони більше тримаються на дронових позиціях.
# [07:58.000 --> 08:07.000]  ФПВ, дрони розвідувальні, а також дрони з ночніками практикують, щоб вичисляти.
# [08:07.000 --> 08:12.000]  Але ми також задніх не пасем.
# [08:12.000 --> 08:22.000]  Тому стараємося їх ліквідовувати як антідроновими пушками, так само з огнепальною зброєю.
# [08:22.000 --> 08:27.000]  Нині бійці на відновленні. Відточують навички та готуються до повернення на схід країни.
# [08:28.000 --> 08:31.000]  Але попередньо ми перевіряємо пушами.
# [08:31.000 --> 08:35.000]  Та навіть тут продовжують захищати українське небо.
# [08:35.000 --> 08:41.000]  На днях наш батальйон збили наші мобільні вогневі групи, збили три шахеди і одну ракету.
# [08:41.000 --> 08:50.000]  Тут на Київщині ви продовжуєте виконувати завдання, збиваєте ворожі шахеди, поронити українське небо.
# [08:50.000 --> 08:55.000]  Я щиро дякую за те, що ви виконували завдання на сході країни,
# [08:55.000 --> 09:02.000]  бренили часів яр, виконували завдання на Бахмутському напрямку.
# [09:02.000 --> 09:08.000]  Робили все залежно від вас для того, щоб наближати нашу славетну перемогу.
# [09:08.000 --> 09:11.000]  Військові показують, як облаштували позиції на Київщині.
# [09:11.000 --> 09:14.000]  Та зізнаються, на сході такої можливості не мають.
# [09:14.000 --> 09:17.000]  Таких брендажів там немає.
# [09:17.000 --> 09:21.000]  Перекриття може бути в один слой, може в два.
# [09:21.000 --> 09:25.000]  Туди на ноль теж бревна ці позатаскували.
# [09:25.000 --> 09:31.000]  Дуже тяжко. Чим скрітніше ми це все зробимо, тим менше ворог знатиме подальші наші дії,
# [09:31.000 --> 09:35.000]  де ми укрепилися, де він може просунутися, де не може.
# [09:35.000 --> 09:39.000]  Це маскування, не так як у критії, а маскування.
# [09:39.000 --> 09:45.000]  В лісі замаскуровався, під лист, під дерева, і ворог вже не знати, скільки у вас там чули.
# [09:45.000 --> 09:47.000]  Та найважче, зізнаються, не це.
# [12:38.000 --> 12:41.000]  Нас звіти телепортирували.
# [12:41.000 --> 12:49.000]  Потім ми пили на ДК Хортецькій, Палацкультури Хортецькій, а потім у травні переїхали сюди.
# [12:49.000 --> 12:54.000]  Зараз в холодному приміщенні грятує єдиний обігрівач та гарячі напої.
# [12:54.000 --> 12:59.000]  Люба – пенсіонерка. Вона працює тут від початку заснування організації.
# [12:59.000 --> 13:03.000]  Каже, що вправність в роботі залежить від досвіду і бажання.
# [13:03.000 --> 13:05.000]  Робити спочатку дуже складно.
# [13:05.000 --> 13:08.000]  Коли приходиш, то поки навчаєшся.
# [13:08.000 --> 13:12.000]  А потім вже, коли навик цих живув, то вже нормально.
# [13:12.000 --> 13:14.000]  Навіть подобається.
# [13:14.000 --> 13:18.000]  Особливо, коли ти знаєш, для чого це робиться.
# [13:18.000 --> 13:21.000]  Що це захищає наші хлопці.
# [13:21.000 --> 13:26.000]  Таким чином приносимо користь, чим можемо в тилу.
# [13:26.000 --> 13:29.000]  Волонтери плетуть сітки для військових щодня.
# [13:29.000 --> 13:31.000]  Збираються різним складом.
# [13:31.000 --> 13:34.000]  Приходять ті, у кого є можливість і на снага.
# [13:34.000 --> 13:38.000]  Матріалами на сітки допомагають інші волонтери і просто небайдужі люди.
# [13:38.000 --> 13:42.000]  Інколи доводиться закупати тканину самотушки.
# [13:42.000 --> 13:55.000]  Якщо ходить 12 людей, то за день можна сплести сітку 6х8, якою можна накрити вантажівку.
# [13:55.000 --> 13:59.000]  Волонтери кажуть, що сітки потрібні щодня на різні напрямки.
# [13:59.000 --> 14:06.000]  Пори року від зимових білих, що маскують підсніг, до весняних, бурих та зеленовато-охрових для літа.
# [14:06.000 --> 14:09.000]  Заказів постійно вистачає.
# [14:09.000 --> 14:17.000]  І на фейсбуці люди бачать, просять замовлення щодня.
# [14:17.000 --> 14:22.000]  Просто ми не встигаємо робити потрібніше людей і приміщення.
# [14:22.000 --> 14:28.000]  Єва Миронова, Олександр Олійник, телеканал «Рада» – загальнонациональний марафон «Єдині новини».

# %%
# !ls
# Out:
# news-uk.json  news-uk.srt  news-uk.txt	sample_data
# news-uk.mp3   news-uk.tsv  news-uk.vtt	whisper-help.txt

# %%
# !mv news-uk.json news-uk-uk.json
# !mv news-uk.srt news-uk-uk.srt
# !mv news-uk.txt	news-uk-uk.txt
# !mv news-uk.tsv news-uk-uk.tsv
# !mv news-uk.vtt news-uk-uk.vtt

# %%
# !whisper news-uk.mp3 --model medium --language Ukrainian --task translate
# Out:
# [00:00.000 --> 00:05.000]  Welcome to the 683rd day of the full-scale war between Russia and Ukraine.
# [00:05.000 --> 00:08.000]  The time of the news is on the air of the General National Marathon.
# [00:08.000 --> 00:10.000]  My name is Olha Butko. Let's get started.
# [00:10.000 --> 00:13.000]  Let's start with the reports from the headquarters of the ZSU.
# [00:13.000 --> 00:16.000]  There were 45 combat clashes on the front line.
# [00:16.000 --> 00:20.000]  The enemy carried out 18 unsuccessful assault actions on the position of the Defense Force.
# [00:20.000 --> 00:26.000]  In particular, in the Avdiivskyi direction, our defenders shot down more than 20 enemy attacks and 9 on the Mariinskyi.
# [09:39.000 --> 09:42.000]  In the forest, he masked himself well, under the forest, under the trees.
# [09:42.000 --> 09:45.000]  And the enemy may not know how many men there are.
# [09:45.000 --> 09:47.000]  But the most difficult thing, they admit, is not this.
# [09:47.000 --> 09:52.000]  It's a pity that some people don't understand that there are people who die there,
# [09:52.000 --> 09:55.000]  and you know them, you have lived with them.
# [09:55.000 --> 10:00.000]  There were moments when we gave our last to survive.
# [10:00.000 --> 10:03.000]  I was asked if there was a lot of loss.
# [10:03.000 --> 10:06.000]  And I said, if I didn't come back, it would be a big loss.
# [10:06.000 --> 10:08.000]  It's a lot of loss.
# [10:08.000 --> 10:10.000]  One person is already a big loss, very big.
# [10:10.000 --> 10:12.000]  He has a family at home.
# [10:12.000 --> 10:15.000]  In two years, we have a minimum loss.
# [10:15.000 --> 10:18.000]  Despite everything, the fighters are confident in victory,
# [10:18.000 --> 10:21.000]  and share the plans they want to implement after the victory.
# [10:21.000 --> 10:24.000]  We go to the bay every year.
# [10:25.000 --> 10:27.000]  At first one, then two.
# [10:27.000 --> 10:29.000]  We rest every year.
# [10:29.000 --> 10:31.000]  We rested in the bay.
# [10:31.000 --> 10:33.000]  I'll take my son to Carpathia.
# [10:33.000 --> 10:37.000]  It will definitely be a family vacation.
# [10:37.000 --> 10:40.000]  And then, where to work or stay,
# [10:40.000 --> 10:44.000]  it will be later to think and make plans for the future.
# [10:44.000 --> 10:48.000]  The main thing for us now is to defeat the enemy
# [10:48.000 --> 10:50.000]  and return home alive.
# [10:54.000 --> 10:57.000]  National Marathon is the only news.
# [10:59.000 --> 11:02.000]  Hundreds of kilometers of camouflage nets for the front.
# [11:02.000 --> 11:05.000]  The oldest volunteer organization in Zaporizhzhia
# [11:05.000 --> 11:08.000]  has recently celebrated its 8th anniversary.
# [11:08.000 --> 11:11.000]  How do volunteers work and what problems do they face,
# [11:11.000 --> 11:14.000]  our correspondents found out.
# [11:14.000 --> 11:17.000]  They work in a cold room that is not heated,
# [11:17.000 --> 11:21.000]  but continue to produce protective nets for the military.
# [11:21.000 --> 11:24.000]  If there were a warm room, we would have more people,
# [11:24.000 --> 11:27.000]  and we would need more people.
# [11:27.000 --> 11:32.000]  There could be about 20 people in a cube at the same time.
# [11:32.000 --> 11:38.000]  So, let's say, five people could cut the cloth,
# [11:38.000 --> 11:41.000]  and the others could weave.
# [11:41.000 --> 11:43.000]  It would be much faster.
# [11:43.000 --> 11:46.000]  Every day, more than 10 people come to weave the nets.
# [11:46.000 --> 11:49.000]  Volunteer Nastia wears a fishing suit every time
# [11:49.000 --> 11:52.000]  to keep up the work at street temperature for half a day,
# [11:52.000 --> 11:55.000]  because there is a heavy motivation.
# [11:55.000 --> 11:58.000]  We sort the cloth bags with which we weave.
# [11:58.000 --> 12:01.000]  They need to be sorted into packs and then cut.
# [12:01.000 --> 12:03.000]  The help of the soldier.
# [12:03.000 --> 12:05.000]  The nets are someone's life.
# [12:05.000 --> 12:07.000]  Each net is someone's life.
# [12:07.000 --> 12:10.000]  It seems to me that there is no other motivation.
# [12:10.000 --> 12:14.000]  The volunteer organization has been working in Zaporizhzhia since 2016.
# [12:14.000 --> 12:17.000]  During this time, it has changed several premises.
# [12:18.000 --> 12:22.000]  This cube was collected in December.
# [12:22.000 --> 12:26.000]  We just finished it on the volunteer day.
# [12:26.000 --> 12:29.000]  We spent six years in the 5th children's hospital.
# [12:29.000 --> 12:34.000]  Then we received reports that we needed permission
# [12:34.000 --> 12:38.000]  to repair the shelter premises.
# [12:38.000 --> 12:41.000]  We were teleported to the reports.
# [12:42.000 --> 12:45.000]  We then sailed to the Khortytskyi district,
# [12:45.000 --> 12:48.000]  the Khortytskyi Palace of Culture,
# [12:48.000 --> 12:50.000]  and then in May we moved here.
# [12:50.000 --> 12:54.000]  Now the only heater and hot drinks are saved in the cold room.
# [12:54.000 --> 12:56.000]  Lyuba is a pensioner.
# [12:56.000 --> 12:59.000]  She has been working here since the beginning of the organization.
# [12:59.000 --> 13:03.000]  She says that the ability to work depends on experience and desire.
# [13:03.000 --> 13:06.000]  It is very difficult to do it at first.
# [13:06.000 --> 13:09.000]  When you come, you need to learn.
# [13:09.000 --> 13:12.000]  When you get used to it, it is already normal.
# [13:12.000 --> 13:14.000]  You even like it.
# [13:14.000 --> 13:18.000]  Especially when you know what it is for.
# [13:18.000 --> 13:21.000]  That it protects our boys.
# [13:21.000 --> 13:26.000]  In the end, we bring this benefit to the rear.
# [13:26.000 --> 13:29.000]  Volunteers weave nets for the military every day.
# [13:29.000 --> 13:31.000]  They gather in different warehouses.
# [13:31.000 --> 13:34.000]  Those come who have the opportunity and the strength.
# [13:34.000 --> 13:38.000]  The materials for the nets are helped by other volunteers and ordinary people.
# [13:38.000 --> 13:41.000]  Sometimes they have to buy the fabric of the cloth.
# [13:41.000 --> 13:46.000]  If there are about 12 people a day,
# [13:46.000 --> 13:55.000]  in two days you can weave a 6x8 net, which can be used to cover the truck.
# [13:55.000 --> 13:59.000]  Volunteers say that the nets are needed every day in different directions.
# [13:59.000 --> 14:00.000]  The time of the year.
# [14:00.000 --> 14:03.000]  From winter white, which is masked by snow,
# [14:03.000 --> 14:06.000]  to spring, storm and ocher green for the summer.
# [14:06.000 --> 14:09.000]  There are always enough orders.
# [14:09.000 --> 14:12.000]  People see it on Facebook.
# [14:12.000 --> 14:17.000]  They ask for a messenger and order every day.
# [14:17.000 --> 14:19.000]  We do not have time to do it.
# [14:19.000 --> 14:22.000]  We need more people and space.
# [14:22.000 --> 14:25.000]  Eva Moronova, Oleksandr Ulynyk, TV channel Rada.
# [14:25.000 --> 14:28.000]  Rada is the only news about the general national marathon.

# %%
# !mv news-uk.json news-uk-en.json
# !mv news-uk.srt news-uk-en.srt
# !mv news-uk.txt	news-uk-en.txt
# !mv news-uk.tsv news-uk-en.tsv
# !mv news-uk.vtt news-uk-en.vtt

# %%
# !tar -cvzf news-uk-all.tgz news-uk*
# Out:
# news-uk-all.tar
# news-uk-en.json
# news-uk-en.srt
# news-uk-en.tsv
# news-uk-en.txt
# news-uk-en.vtt
# news-uk.mp3
# news-uk-uk.json
# news-uk-uk.srt
# news-uk-uk.tsv
# news-uk-uk.txt
# news-uk-uk.vtt

# %%
# !whisper --help >whisper-help.txt
