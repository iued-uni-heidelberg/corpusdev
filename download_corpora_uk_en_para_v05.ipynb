# %% [markdown]
# <a href="https://colab.research.google.com/github/iued-uni-heidelberg/corpusdev/blob/main/download_corpora_uk_en_para_v05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Download Ukrainian corpus
# ## Corpus from the UK domain

# %% [markdown]
# militarnyi corpus

# %%
# !rm -r -f /content/militarnyi.com

# %%
# !wget --recursive --accept html https://militarnyi.com/

# %%
# !wget --continue -e robots=off --recursive --accept html https://militarnyi.com/

# %%
# !wget --continue -e robots=off --recursive https://militarnyi.com/
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# Saving to: ‘militarnyi.com/uk/news/brytaniya-ta-frantsiya-zavdaly-udariv-po-tunelyah-id-u-syriyi/index.html’
#
# militarnyi.com/uk/n     [ <=>                ] 171.77K  --.-KB/s    in 0.004s
#
# 2026-04-30 11:33:21 (41.0 MB/s) - ‘militarnyi.com/uk/news/brytaniya-ta-frantsiya-zavdaly-udariv-po-tunelyah-id-u-syriyi/index.html’ saved [175892]
#
# --2026-04-30 11:33:21--  https://militarnyi.com/wp-content/uploads/2024/01/Screenshot_2-45-300x172.jpg
# Reusing existing connection to militarnyi.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8689 (8.5K) [image/jpeg]
# Saving to: ‘militarnyi.com/wp-content/uploads/2024/01/Screenshot_2-45-300x172.jpg’
#
# militarnyi.com/wp-c 100%[===================>]   8.49K  --.-KB/s    in 0s
#
# 2026-04-30 11:33:22 (148 MB/s) - ‘militarnyi.com/wp-content/uploads/2024/01/Screenshot_2-45-300x172.jpg’ saved [8689/8689]
#
# ...

# %%
# !tar -cvzf militarnyi.com-2G.tgz /content/militarnyi.com

# %% [markdown]
# defence com ua corpus

# %%
# !rm -r -f /content/defence-ua.com

# %%
# !wget --recursive --accept html https://defence-ua.com/

# %%
# !zip -r defence-ua.com.zip /content/defence-ua.com

# %% [markdown]
# ## Corpus from the EN domain

# %%
# !rm -r -f /content/en.defence-ua.com

# %%
# !wget --recursive --accept html https://en.defence-ua.com/

# %%
# !zip -r en.defence-ua.com.zip /content/en.defence-ua.com

# %%
# !zip -r gesetze-im-internet--de.zip /content/www.gesetze-im-internet.de

# %% [markdown]
# ## Installing and using lynx browser: dump function

# %%
# !apt-get update && apt-get install lynx -y

# %%
# !lynx -dump /content/defence-ua.com/weapon_and_tech/amerikanska_zolota_orda_niveljuje_potentsial_ppo_voroga_novi_viprobuvannja_rozumnih_merezhevih_aviabojepripasiv-3796.html > /content/3796.txt

# %%
# !lynx -dump /content/defence-ua.com/weapon_and_tech/administratsija_bajdena_galmuje_prodazh_novih_raket_saudivskij_araviji_prichina_strah_pered_iranom-5554.html >/content/5554-en.txt

# %%
# !lynx -dump /content/en.defence-ua.com/weapon_and_tech/active_war_simpler_drones_ukrainian_military_operate_domestically_made_cheap_chaklun_uav_video-5643.html >/content/5643--en.txt

# %% [markdown]
# ## Terminal commands to find files
#
#
# ```
# /content# du -sh defence-ua.com/
# 1.8G    defence-ua.com/
# /content# du -sh defence-ua.com/
# 2.2G    defence-ua.com/
# /content# find /content/defence-ua.com/ -name "*-5554.html"
# /content/defence-ua.com/weapon_and_tech/administratsija_bajdena_galmuje_prodazh_novih_raket_saudivskij_araviji_prichina_strah_pered_iranom-5554.html
# /content# find /content/en.defence-ua.com/ -name "*-5554.html"
# /content# find /content/en.defence-ua.com/ -name "*-5643.html"
# /content/en.defence-ua.com/weapon_and_tech/active_war_simpler_drones_ukrainian_military_operate_domestically_made_cheap_chaklun_uav_video-5643.html
# /content# find /content/defence-ua.com/ -name "*-5643.html"
# /content/defence-ua.com/people_and_company/dp_antonov_pidpisalo_kontrakt_z_dsns_na_pjatij_an_32p_video-5643.html
# /content#
#
# du -sh militarnyi.com/
#
#
#
# ```
